# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# Loading the results files

file_path_0 = 'TD3_MountainCarContinuous-v0_0.npy'  # modify here
file_path_1 = 'TD3_MountainCarContinuous-v0_1.npy'  # modify here
file_path_2 = 'TD3_MountainCarContinuous-v0_2.npy'  # modify here


# ---------------- SEED 0 --------------------

# Check if the file exists
if os.path.exists(file_path_0):
    # Load the array from a .npy file
    data0 = np.load(file_path_0)
    print(data0)
else:
    print(f"File not found: {file_path_0}. Check the file name and path.")


# ---------------- SEED 1 --------------------

# Check if the file exists
if os.path.exists(file_path_1):
    # Load the array from a .npy file
    data1 = np.load(file_path_1)
    #print(data0)
else:
    print(f"File not found: {file_path_1}. Check the file name and path.")


# ---------------- SEED 2 --------------------

# Check if the file exists
if os.path.exists(file_path_2):
    # Load the array from a .npy file
    data2 = np.load(file_path_2)
    #print(data0)
else:
    print(f"File not found: {file_path_2}. Check the file name and path.")
# Out:
# [-2.77058271e-01 -2.77058271e-01 -2.77058271e-01 -2.77058271e-01
#  -2.77058271e-01 -2.77058271e-01 -4.49684267e-02 -7.77134448e-02
#  -1.33449467e-02 -4.64235425e-02 -2.56166803e-02 -1.04709362e-01
#   4.60886713e+01  9.12235110e+01  8.77264287e+01  9.28115078e+01
#   9.26895439e+01  9.27847950e+01  9.28901421e+01  9.30652881e+01
#   9.31260636e+01  9.31619264e+01  9.31671632e+01  9.31835272e+01
#   9.32003086e+01  9.33232568e+01  9.33934252e+01  9.33563885e+01
#   9.34126855e+01  9.34856679e+01  9.34152714e+01]

# %%
# Plotting

# Generating x-axis values (timesteps)
timesteps = np.arange(0, len(data1) * 5000, 5000)


# Plotting
plt.plot(timesteps, data0, label='seed 0')
plt.plot(timesteps, data1, label='seed 1')
plt.plot(timesteps, data2, label='seed 2')
plt.xlabel('Timesteps')
plt.ylabel('Average Reward')
plt.title('TD3 Mountain Car Continuous v0')
plt.legend()
plt.grid(True)

# Save the plot
plt.savefig('CHANGETHENAMEHERE.png') #modify file name !!!!!!!!!!!!!!!!!!!!!

# Show the plot
plt.show()
