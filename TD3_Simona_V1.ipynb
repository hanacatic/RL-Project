# %% [markdown]
# **TD3**

# %% [markdown]
# python main.py \
# --policy "TD3" \
# --env "MountainCar-v0" \
# -- seed $i \
# --start_timesteps 1000

# %%
#IMPORTS

# TD3
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# Main
import numpy as np
import torch
import gym
import argparse
import os

import utils
#import TD3
import OurDDPG
import DDPG

# Visualization
import gym

# %%
# Parameters settings

class Args:
    policy = "TD3"                  # Policy name (TD3, DDPG, or OurDDPG)
    env = "MountainCarContinuous-v0"          # OpenAI gym environment name
    seed = 0                        # Sets Gym, PyTorch, and Numpy seeds
    start_timesteps = 25000         # Time steps initial random policy is used
    eval_freq = 5000                # How often (time steps) we evaluate
    max_timesteps = 1000000         # Max time steps to run environment
    expl_noise = 5 #0.1                # Std of Gaussian exploration noise
    batch_size = 64 #256               # Batch size for both actor and critic
    discount = 0.99                 # Discount factor
    tau = 0.005                     # Target network update rate
    policy_noise = 0.2 #0.2              # Noise added to target policy during critic update
    noise_clip = 0.5                # Range to clip target policy noise
    policy_freq = 2                 # Frequency of delayed policy updates
    save_model = False              # Save model and optimizer parameters
    load_model = ""                 # Model load file name, "" doesn't load, "default" uses file_name

# %%
#TD3 FILE





device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
	def __init__(self, state_dim, action_dim, max_action):
		super(Actor, self).__init__()

		self.l1 = nn.Linear(state_dim, 16)
		self.l2 = nn.Linear(16, 16)
		self.l3 = nn.Linear(16, action_dim)
		
		self.max_action = max_action
		

	def forward(self, state):
		a = F.relu(self.l1(state))
		a = F.relu(self.l2(a))
		return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
	def __init__(self, state_dim, action_dim):
		super(Critic, self).__init__()

		# Q1 architecture
		self.l1 = nn.Linear(state_dim + action_dim, 16) # 256
		self.l2 = nn.Linear(16, 16)
		self.l3 = nn.Linear(16, 1)

		# Q2 architecture
		self.l4 = nn.Linear(state_dim + action_dim, 16)
		self.l5 = nn.Linear(16, 16)
		self.l6 = nn.Linear(16, 1)


	def forward(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)

		q2 = F.relu(self.l4(sa))
		q2 = F.relu(self.l5(q2))
		q2 = self.l6(q2)
		return q1, q2


	def Q1(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)
		return q1


class TD3(object):
	def __init__(
		self,
		state_dim,
		action_dim,
		max_action,
		discount=0.99,
		tau=0.005,
		policy_noise=0.2,
		noise_clip=0.5,
		policy_freq=2
	):

		self.actor = Actor(state_dim, action_dim, max_action).to(device)
		self.actor_target = copy.deepcopy(self.actor)
		self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

		self.critic = Critic(state_dim, action_dim).to(device)
		self.critic_target = copy.deepcopy(self.critic)
		self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

		self.max_action = max_action
		self.discount = discount
		self.tau = tau
		self.policy_noise = policy_noise
		self.noise_clip = noise_clip
		self.policy_freq = policy_freq

		self.total_it = 0


	def select_action(self, state):
		state = torch.FloatTensor(state.reshape(1, -1)).to(device)
		return self.actor(state).cpu().data.numpy().flatten()


	def train(self, replay_buffer, batch_size=256):
		self.total_it += 1

		# Sample replay buffer 
		state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

		with torch.no_grad():
			# Select action according to policy and add clipped noise
			noise = (
				torch.randn_like(action) * self.policy_noise
			).clamp(-self.noise_clip, self.noise_clip)
			
			next_action = (
				self.actor_target(next_state) + noise
			).clamp(-self.max_action, self.max_action)

			# Compute the target Q value
			target_Q1, target_Q2 = self.critic_target(next_state, next_action)
			target_Q = torch.min(target_Q1, target_Q2)
			target_Q = reward + not_done * self.discount * target_Q

		# Get current Q estimates
		current_Q1, current_Q2 = self.critic(state, action)

		# Compute critic loss
		critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

		# Optimize the critic
		self.critic_optimizer.zero_grad()
		critic_loss.backward()
		self.critic_optimizer.step()

		# Delayed policy updates
		if self.total_it % self.policy_freq == 0:

			# Compute actor losse
			actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
			
			# Optimize the actor 
			self.actor_optimizer.zero_grad()
			actor_loss.backward()
			self.actor_optimizer.step()

			# Update the frozen target models
			for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

			for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)


	def save(self, filename):
		torch.save(self.critic.state_dict(), filename + "_critic")
		torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")
		
		torch.save(self.actor.state_dict(), filename + "_actor")
		torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")


	def load(self, filename):
		self.critic.load_state_dict(torch.load(filename + "_critic"))
		self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
		self.critic_target = copy.deepcopy(self.critic)

		self.actor.load_state_dict(torch.load(filename + "_actor"))
		self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
		self.actor_target = copy.deepcopy(self.actor)

# %%
# MAIN FILE


# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env_name, seed, eval_episodes=10):
	eval_env = gym.make(env_name)
	eval_env.seed(seed + 100)

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward


if __name__ == "__main__":
	
	'''
	parser = argparse.ArgumentParser()
	parser.add_argument("--policy", default="TD3")                  # Policy name (TD3, DDPG or OurDDPG)
	parser.add_argument("--env", default="HalfCheetah-v2")          # OpenAI gym environment name
	parser.add_argument("--seed", default=0, type=int)              # Sets Gym, PyTorch and Numpy seeds
	parser.add_argument("--start_timesteps", default=25e3, type=int)# Time steps initial random policy is used
	parser.add_argument("--eval_freq", default=5e3, type=int)       # How often (time steps) we evaluate
	parser.add_argument("--max_timesteps", default=1e6, type=int)   # Max time steps to run environment
	parser.add_argument("--expl_noise", default=0.1, type=float)    # Std of Gaussian exploration noise
	parser.add_argument("--batch_size", default=256, type=int)      # Batch size for both actor and critic
	parser.add_argument("--discount", default=0.99, type=float)     # Discount factor
	parser.add_argument("--tau", default=0.005, type=float)         # Target network update rate
	parser.add_argument("--policy_noise", default=0.2)              # Noise added to target policy during critic update
	parser.add_argument("--noise_clip", default=0.5)                # Range to clip target policy noise
	parser.add_argument("--policy_freq", default=2, type=int)       # Frequency of delayed policy updates
	parser.add_argument("--save_model", action="store_true")        # Save model and optimizer parameters
	parser.add_argument("--load_model", default="")                 # Model load file name, "" doesn't load, "default" uses file_name
	args = parser.parse_args()
	'''
	args = Args()

	file_name = f"{args.policy}_{args.env}_{args.seed}"
	print("---------------------------------------")
	print(f"Policy: {args.policy}, Env: {args.env}, Seed: {args.seed}")
	print("---------------------------------------")

	if not os.path.exists("./results"):
		os.makedirs("./results")

	if args.save_model and not os.path.exists("./models"):
		os.makedirs("./models")

	env = gym.make(args.env)

	# Set seeds
	env.seed(args.seed)
	env.action_space.seed(args.seed)
	torch.manual_seed(args.seed)
	np.random.seed(args.seed)
	
	state_dim = env.observation_space.shape[0]
	action_dim = env.action_space.shape[0] 
	max_action = float(env.action_space.high[0])

	kwargs = {
		"state_dim": state_dim,
		"action_dim": action_dim,
		"max_action": max_action,
		"discount": args.discount,
		"tau": args.tau,
	}

	# Initialize policy
	if args.policy == "TD3":
		# Target policy smoothing is scaled wrt the action scale
		kwargs["policy_noise"] = args.policy_noise * max_action
		kwargs["noise_clip"] = args.noise_clip * max_action
		kwargs["policy_freq"] = args.policy_freq
		#policy = TD3.TD3(**kwargs)
		policy = TD3(**kwargs)
	elif args.policy == "OurDDPG":
		policy = OurDDPG.DDPG(**kwargs)
	elif args.policy == "DDPG":
		policy = DDPG.DDPG(**kwargs)

	if args.load_model != "":
		policy_file = file_name if args.load_model == "default" else args.load_model
		policy.load(f"./models/{policy_file}")

	replay_buffer = utils.ReplayBuffer(state_dim, action_dim)
	
	# Evaluate untrained policy
	evaluations = [eval_policy(policy, args.env, args.seed)]

	state, done = env.reset(), False
	episode_reward = 0
	episode_timesteps = 0
	episode_num = 0

	for t in range(int(args.max_timesteps)):
		
		episode_timesteps += 1

		# Select action randomly or according to policy
		if t < args.start_timesteps:
			action = env.action_space.sample()
		else:
			action = (
				policy.select_action(np.array(state))
				+ np.random.normal(0, max_action * args.expl_noise - 0.0001, size=action_dim) # I added the - 0.001 because we want to reduce the exploration noise
			).clip(-max_action, max_action)

		# Perform action
		next_state, reward, done, _ = env.step(action) 
		done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

		# Store data in replay buffer
		replay_buffer.add(state, action, next_state, reward, done_bool)

		state = next_state
		episode_reward += reward

		# Train agent after collecting sufficient data
		if t >= args.start_timesteps:
			policy.train(replay_buffer, args.batch_size)

		if done: 
			# +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
			print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
			# Reset environment
			state, done = env.reset(), False
			episode_reward = 0
			episode_timesteps = 0
			episode_num += 1 

		# Evaluate episode
		if (t + 1) % args.eval_freq == 0:
			evaluations.append(eval_policy(policy, args.env, args.seed))
			np.save(f"./results/{file_name}", evaluations)
			if args.save_model: policy.save(f"./models/{file_name}")
# Out:
# ---------------------------------------
# Policy: TD3, Env: MountainCarContinuous-v0, Seed: 0
# ---------------------------------------
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 999 Episode Num: 1 Episode T: 999 Reward: -32.504
# Total T: 1998 Episode Num: 2 Episode T: 999 Reward: -35.036
# Total T: 2997 Episode Num: 3 Episode T: 999 Reward: -32.692
# Total T: 3996 Episode Num: 4 Episode T: 999 Reward: -32.465
# Total T: 4995 Episode Num: 5 Episode T: 999 Reward: -35.142
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 5994 Episode Num: 6 Episode T: 999 Reward: -32.234
# Total T: 6993 Episode Num: 7 Episode T: 999 Reward: -34.059
# Total T: 7992 Episode Num: 8 Episode T: 999 Reward: -33.792
# Total T: 8991 Episode Num: 9 Episode T: 999 Reward: -33.278
# Total T: 9990 Episode Num: 10 Episode T: 999 Reward: -32.696
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 10989 Episode Num: 11 Episode T: 999 Reward: -32.580
# Total T: 11988 Episode Num: 12 Episode T: 999 Reward: -33.955
# Total T: 12987 Episode Num: 13 Episode T: 999 Reward: -33.182
# Total T: 13986 Episode Num: 14 Episode T: 999 Reward: -33.186
# Total T: 14985 Episode Num: 15 Episode T: 999 Reward: -32.310
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 15984 Episode Num: 16 Episode T: 999 Reward: -32.807
# Total T: 16983 Episode Num: 17 Episode T: 999 Reward: -31.836
# Total T: 17982 Episode Num: 18 Episode T: 999 Reward: -33.139
# Total T: 18981 Episode Num: 19 Episode T: 999 Reward: -32.588
# Total T: 19980 Episode Num: 20 Episode T: 999 Reward: -32.118
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 20979 Episode Num: 21 Episode T: 999 Reward: -32.293
# Total T: 21978 Episode Num: 22 Episode T: 999 Reward: -32.756
# Total T: 22977 Episode Num: 23 Episode T: 999 Reward: -32.745
# Total T: 23976 Episode Num: 24 Episode T: 999 Reward: -31.752
# Total T: 24975 Episode Num: 25 Episode T: 999 Reward: -33.952
# ---------------------------------------
# Evaluation over 10 episodes: -5.819
# ---------------------------------------
# Total T: 25974 Episode Num: 26 Episode T: 999 Reward: -87.902
# Total T: 26973 Episode Num: 27 Episode T: 999 Reward: -88.734
# Total T: 27972 Episode Num: 28 Episode T: 999 Reward: -89.699
# Total T: 28971 Episode Num: 29 Episode T: 999 Reward: -88.059
# Total T: 29970 Episode Num: 30 Episode T: 999 Reward: -88.407
# ---------------------------------------
# Evaluation over 10 episodes: -0.043
# ---------------------------------------
# Total T: 30969 Episode Num: 31 Episode T: 999 Reward: -89.872
# Total T: 31968 Episode Num: 32 Episode T: 999 Reward: -90.185
# Total T: 32967 Episode Num: 33 Episode T: 999 Reward: -89.931
# Total T: 33966 Episode Num: 34 Episode T: 999 Reward: -88.663
# Total T: 34965 Episode Num: 35 Episode T: 999 Reward: -88.490
# ---------------------------------------
# Evaluation over 10 episodes: -1.001
# ---------------------------------------
# Total T: 35964 Episode Num: 36 Episode T: 999 Reward: -89.779
# Total T: 36963 Episode Num: 37 Episode T: 999 Reward: -90.668
# Total T: 37962 Episode Num: 38 Episode T: 999 Reward: -90.774
# Total T: 38961 Episode Num: 39 Episode T: 999 Reward: -88.873
# Total T: 39960 Episode Num: 40 Episode T: 999 Reward: -90.983
# ---------------------------------------
# Evaluation over 10 episodes: -0.443
# ---------------------------------------
# Total T: 40959 Episode Num: 41 Episode T: 999 Reward: -88.444
# Total T: 41958 Episode Num: 42 Episode T: 999 Reward: -89.346
# Total T: 42957 Episode Num: 43 Episode T: 999 Reward: -88.691
# Total T: 43956 Episode Num: 44 Episode T: 999 Reward: -88.869
# Total T: 44955 Episode Num: 45 Episode T: 999 Reward: -90.311
# ---------------------------------------
# Evaluation over 10 episodes: -0.273
# ---------------------------------------
# Total T: 45954 Episode Num: 46 Episode T: 999 Reward: -89.255
# Total T: 46953 Episode Num: 47 Episode T: 999 Reward: -88.527
# Total T: 47952 Episode Num: 48 Episode T: 999 Reward: -89.110
# Total T: 48951 Episode Num: 49 Episode T: 999 Reward: -90.409
# Total T: 49950 Episode Num: 50 Episode T: 999 Reward: -88.631
# ---------------------------------------
# Evaluation over 10 episodes: -0.240
# ---------------------------------------
# Total T: 50949 Episode Num: 51 Episode T: 999 Reward: -88.732
# Total T: 51948 Episode Num: 52 Episode T: 999 Reward: -91.357
# Total T: 52870 Episode Num: 53 Episode T: 922 Reward: 18.007
# Total T: 53869 Episode Num: 54 Episode T: 999 Reward: -88.909
# Total T: 54868 Episode Num: 55 Episode T: 999 Reward: -89.248
# ---------------------------------------
# Evaluation over 10 episodes: -0.097
# ---------------------------------------
# Total T: 55867 Episode Num: 56 Episode T: 999 Reward: -89.478
# Total T: 56866 Episode Num: 57 Episode T: 999 Reward: -88.643
# Total T: 57865 Episode Num: 58 Episode T: 999 Reward: -90.658
# Total T: 58864 Episode Num: 59 Episode T: 999 Reward: -89.743
# Total T: 59863 Episode Num: 60 Episode T: 999 Reward: -87.879
# ---------------------------------------
# Evaluation over 10 episodes: -0.208
# ---------------------------------------
# Total T: 60862 Episode Num: 61 Episode T: 999 Reward: -89.289
# Total T: 61739 Episode Num: 62 Episode T: 877 Reward: 22.239
# Total T: 62738 Episode Num: 63 Episode T: 999 Reward: -88.691
# Total T: 63357 Episode Num: 64 Episode T: 619 Reward: 45.106
# Total T: 64356 Episode Num: 65 Episode T: 999 Reward: -88.865
# ---------------------------------------
# Evaluation over 10 episodes: -2.461
# ---------------------------------------
# Total T: 65355 Episode Num: 66 Episode T: 999 Reward: -89.099
# Total T: 66354 Episode Num: 67 Episode T: 999 Reward: -89.188
# Total T: 67353 Episode Num: 68 Episode T: 999 Reward: -88.268
# Total T: 68352 Episode Num: 69 Episode T: 999 Reward: -90.463
# Total T: 69351 Episode Num: 70 Episode T: 999 Reward: -90.422
# Total T: 69832 Episode Num: 71 Episode T: 481 Reward: 57.222
# ---------------------------------------
# Evaluation over 10 episodes: -0.258
# ---------------------------------------
# Total T: 70831 Episode Num: 72 Episode T: 999 Reward: -90.438
# Total T: 71830 Episode Num: 73 Episode T: 999 Reward: -89.209
# Total T: 72829 Episode Num: 74 Episode T: 999 Reward: -89.310
# Total T: 73828 Episode Num: 75 Episode T: 999 Reward: -87.505
# Total T: 74827 Episode Num: 76 Episode T: 999 Reward: -89.994
# ---------------------------------------
# Evaluation over 10 episodes: -5.570
# ---------------------------------------
# Total T: 75826 Episode Num: 77 Episode T: 999 Reward: -89.752
# Total T: 76825 Episode Num: 78 Episode T: 999 Reward: -88.887
# Total T: 77824 Episode Num: 79 Episode T: 999 Reward: -89.855
# Total T: 78823 Episode Num: 80 Episode T: 999 Reward: -89.727
# Total T: 79326 Episode Num: 81 Episode T: 503 Reward: 54.542
# ---------------------------------------
# Evaluation over 10 episodes: -0.691
# ---------------------------------------
# Total T: 80325 Episode Num: 82 Episode T: 999 Reward: -89.426
# Total T: 81324 Episode Num: 83 Episode T: 999 Reward: -90.695
# Total T: 82323 Episode Num: 84 Episode T: 999 Reward: -90.075
# Total T: 83322 Episode Num: 85 Episode T: 999 Reward: -88.843
# Total T: 84321 Episode Num: 86 Episode T: 999 Reward: -89.361
# ---------------------------------------
# Evaluation over 10 episodes: -5.592
# ---------------------------------------
# Total T: 85320 Episode Num: 87 Episode T: 999 Reward: -89.979
# Total T: 86319 Episode Num: 88 Episode T: 999 Reward: -88.551
# Total T: 87318 Episode Num: 89 Episode T: 999 Reward: -89.588
# Total T: 88317 Episode Num: 90 Episode T: 999 Reward: -89.724
# Total T: 89316 Episode Num: 91 Episode T: 999 Reward: -89.916
# ---------------------------------------
# Evaluation over 10 episodes: -5.710
# ---------------------------------------
# Total T: 90148 Episode Num: 92 Episode T: 832 Reward: 25.980
# Total T: 91147 Episode Num: 93 Episode T: 999 Reward: -90.008
# Total T: 92146 Episode Num: 94 Episode T: 999 Reward: -90.137
# Total T: 93145 Episode Num: 95 Episode T: 999 Reward: -89.278
# Total T: 94115 Episode Num: 96 Episode T: 970 Reward: 11.667
# ---------------------------------------
# Evaluation over 10 episodes: -4.966
# ---------------------------------------
# Total T: 95114 Episode Num: 97 Episode T: 999 Reward: -89.026
# Total T: 95909 Episode Num: 98 Episode T: 795 Reward: 28.301
# Total T: 96682 Episode Num: 99 Episode T: 773 Reward: 30.934
# Total T: 97254 Episode Num: 100 Episode T: 572 Reward: 49.082
# Total T: 98253 Episode Num: 101 Episode T: 999 Reward: -89.865
# Total T: 99252 Episode Num: 102 Episode T: 999 Reward: -88.582
# ---------------------------------------
# Evaluation over 10 episodes: -4.805
# ---------------------------------------
# Total T: 100251 Episode Num: 103 Episode T: 999 Reward: -89.656
# Total T: 101007 Episode Num: 104 Episode T: 756 Reward: 32.267
# Total T: 101981 Episode Num: 105 Episode T: 974 Reward: 12.143
# Total T: 102979 Episode Num: 106 Episode T: 998 Reward: 9.562
# Total T: 103978 Episode Num: 107 Episode T: 999 Reward: -90.009
# Total T: 104977 Episode Num: 108 Episode T: 999 Reward: -89.923
# ---------------------------------------
# Evaluation over 10 episodes: -5.060
# ---------------------------------------
# Total T: 105695 Episode Num: 109 Episode T: 718 Reward: 36.032
# Total T: 106431 Episode Num: 110 Episode T: 736 Reward: 34.086
# Total T: 107430 Episode Num: 111 Episode T: 999 Reward: -90.097
# Total T: 108429 Episode Num: 112 Episode T: 999 Reward: -89.583
# Total T: 109428 Episode Num: 113 Episode T: 999 Reward: -90.110
# ---------------------------------------
# Evaluation over 10 episodes: -6.044
# ---------------------------------------
# Total T: 110427 Episode Num: 114 Episode T: 999 Reward: -89.416
# Total T: 111426 Episode Num: 115 Episode T: 999 Reward: -88.435
# Total T: 112425 Episode Num: 116 Episode T: 999 Reward: -90.557
# Total T: 113220 Episode Num: 117 Episode T: 795 Reward: 28.118
# Total T: 114219 Episode Num: 118 Episode T: 999 Reward: -88.125
# ---------------------------------------
# Evaluation over 10 episodes: -7.298
# ---------------------------------------
# Total T: 115218 Episode Num: 119 Episode T: 999 Reward: -89.055
# Total T: 116217 Episode Num: 120 Episode T: 999 Reward: -91.376
# Total T: 117216 Episode Num: 121 Episode T: 999 Reward: -90.175
# Total T: 118215 Episode Num: 122 Episode T: 999 Reward: -89.493
# Total T: 119084 Episode Num: 123 Episode T: 869 Reward: 24.013
# ---------------------------------------
# Evaluation over 10 episodes: -8.084
# ---------------------------------------
# Total T: 120083 Episode Num: 124 Episode T: 999 Reward: -88.433
# Total T: 121082 Episode Num: 125 Episode T: 999 Reward: -89.494
# Total T: 122081 Episode Num: 126 Episode T: 999 Reward: -88.986
# Total T: 123080 Episode Num: 127 Episode T: 999 Reward: -88.739
# Total T: 124079 Episode Num: 128 Episode T: 999 Reward: -87.584
# ---------------------------------------
# Evaluation over 10 episodes: -3.436
# ---------------------------------------
# Total T: 125078 Episode Num: 129 Episode T: 999 Reward: -90.563
# Total T: 126077 Episode Num: 130 Episode T: 999 Reward: -89.383
# Total T: 126440 Episode Num: 131 Episode T: 363 Reward: 67.122
# Total T: 127439 Episode Num: 132 Episode T: 999 Reward: -89.522
# Total T: 128438 Episode Num: 133 Episode T: 999 Reward: -89.726
# Total T: 129437 Episode Num: 134 Episode T: 999 Reward: -88.431
# ---------------------------------------
# Evaluation over 10 episodes: 15.049
# ---------------------------------------
# Total T: 130436 Episode Num: 135 Episode T: 999 Reward: -89.397
# Total T: 131435 Episode Num: 136 Episode T: 999 Reward: -89.600
# Total T: 131911 Episode Num: 137 Episode T: 476 Reward: 56.310
# Total T: 132765 Episode Num: 138 Episode T: 854 Reward: 23.987
# Total T: 133454 Episode Num: 139 Episode T: 689 Reward: 39.270
# Total T: 134243 Episode Num: 140 Episode T: 789 Reward: 28.677
# Total T: 134626 Episode Num: 141 Episode T: 383 Reward: 65.723
# ---------------------------------------
# Evaluation over 10 episodes: 92.418
# ---------------------------------------
# Total T: 135215 Episode Num: 142 Episode T: 589 Reward: 47.179
# Total T: 135960 Episode Num: 143 Episode T: 745 Reward: 32.335
# Total T: 136740 Episode Num: 144 Episode T: 780 Reward: 29.582
# Total T: 137501 Episode Num: 145 Episode T: 761 Reward: 32.469
# Total T: 138500 Episode Num: 146 Episode T: 999 Reward: -88.924
# Total T: 139499 Episode Num: 147 Episode T: 999 Reward: -89.108
# ---------------------------------------
# Evaluation over 10 episodes: 84.962
# ---------------------------------------
# Total T: 140498 Episode Num: 148 Episode T: 999 Reward: -90.564
# Total T: 141497 Episode Num: 149 Episode T: 999 Reward: -89.715
# Total T: 142496 Episode Num: 150 Episode T: 999 Reward: -88.971
# Total T: 143018 Episode Num: 151 Episode T: 522 Reward: 53.302
# Total T: 143742 Episode Num: 152 Episode T: 724 Reward: 35.356
# Total T: 144189 Episode Num: 153 Episode T: 447 Reward: 59.400
# ---------------------------------------
# Evaluation over 10 episodes: -5.792
# ---------------------------------------
# Total T: 145188 Episode Num: 154 Episode T: 999 Reward: -89.416
# Total T: 146187 Episode Num: 155 Episode T: 999 Reward: -88.905
# Total T: 146783 Episode Num: 156 Episode T: 596 Reward: 45.143
# Total T: 147782 Episode Num: 157 Episode T: 999 Reward: -90.295
# Total T: 148781 Episode Num: 158 Episode T: 999 Reward: -87.831
# Total T: 149780 Episode Num: 159 Episode T: 999 Reward: -89.541
# ---------------------------------------
# Evaluation over 10 episodes: -73.924
# ---------------------------------------
# Total T: 150779 Episode Num: 160 Episode T: 999 Reward: -89.480
# Total T: 151778 Episode Num: 161 Episode T: 999 Reward: -89.670
# Total T: 152690 Episode Num: 162 Episode T: 912 Reward: 17.901
# Total T: 153689 Episode Num: 163 Episode T: 999 Reward: -88.465
# Total T: 154461 Episode Num: 164 Episode T: 772 Reward: 29.820
# ---------------------------------------
# Evaluation over 10 episodes: -79.578
# ---------------------------------------
# Total T: 155460 Episode Num: 165 Episode T: 999 Reward: -88.664
# Total T: 156459 Episode Num: 166 Episode T: 999 Reward: -89.695
# Total T: 157458 Episode Num: 167 Episode T: 999 Reward: -89.793
# Total T: 158457 Episode Num: 168 Episode T: 999 Reward: -89.508
# Total T: 159456 Episode Num: 169 Episode T: 999 Reward: -90.002
# ---------------------------------------
# Evaluation over 10 episodes: -99.491
# ---------------------------------------
# Total T: 160455 Episode Num: 170 Episode T: 999 Reward: -87.920
# Total T: 161454 Episode Num: 171 Episode T: 999 Reward: -88.518
# Total T: 162453 Episode Num: 172 Episode T: 999 Reward: -90.360
# Total T: 163452 Episode Num: 173 Episode T: 999 Reward: -90.363
# Total T: 164451 Episode Num: 174 Episode T: 999 Reward: -89.546
# ---------------------------------------
# Evaluation over 10 episodes: -99.267
# ---------------------------------------
# Total T: 165450 Episode Num: 175 Episode T: 999 Reward: -90.321
# Total T: 166449 Episode Num: 176 Episode T: 999 Reward: -88.323
# Total T: 167448 Episode Num: 177 Episode T: 999 Reward: -88.531
# Total T: 168434 Episode Num: 178 Episode T: 986 Reward: 11.468
# Total T: 169433 Episode Num: 179 Episode T: 999 Reward: -88.773
# ---------------------------------------
# Evaluation over 10 episodes: 52.715
# ---------------------------------------
# Total T: 170432 Episode Num: 180 Episode T: 999 Reward: -88.663
# Total T: 171431 Episode Num: 181 Episode T: 999 Reward: -90.174
# Total T: 172430 Episode Num: 182 Episode T: 999 Reward: -89.527
# Total T: 173429 Episode Num: 183 Episode T: 999 Reward: -88.359
# Total T: 174065 Episode Num: 184 Episode T: 636 Reward: 42.640
# ---------------------------------------
# Evaluation over 10 episodes: 28.085
# ---------------------------------------
# Total T: 175064 Episode Num: 185 Episode T: 999 Reward: -89.963
# Total T: 175599 Episode Num: 186 Episode T: 535 Reward: 51.167
# Total T: 176598 Episode Num: 187 Episode T: 999 Reward: -89.919
# Total T: 177597 Episode Num: 188 Episode T: 999 Reward: -89.224
# Total T: 178474 Episode Num: 189 Episode T: 877 Reward: 21.419
# Total T: 179473 Episode Num: 190 Episode T: 999 Reward: -89.002
# ---------------------------------------
# Evaluation over 10 episodes: -99.671
# ---------------------------------------
# Total T: 180472 Episode Num: 191 Episode T: 999 Reward: -88.889
# Total T: 181471 Episode Num: 192 Episode T: 999 Reward: -90.110
# Total T: 182470 Episode Num: 193 Episode T: 999 Reward: -90.330
# Total T: 183469 Episode Num: 194 Episode T: 999 Reward: -88.698
# Total T: 184468 Episode Num: 195 Episode T: 999 Reward: -89.788
# ---------------------------------------
# Evaluation over 10 episodes: -99.900
# ---------------------------------------
# Total T: 185467 Episode Num: 196 Episode T: 999 Reward: -90.080
# Total T: 185856 Episode Num: 197 Episode T: 389 Reward: 65.110
# Total T: 186599 Episode Num: 198 Episode T: 743 Reward: 33.639
# Total T: 187598 Episode Num: 199 Episode T: 999 Reward: -91.256
# Total T: 188597 Episode Num: 200 Episode T: 999 Reward: -90.138
# Total T: 189366 Episode Num: 201 Episode T: 769 Reward: 31.313
# ---------------------------------------
# Evaluation over 10 episodes: -99.900
# ---------------------------------------
# Total T: 190365 Episode Num: 202 Episode T: 999 Reward: -89.489
# Total T: 191352 Episode Num: 203 Episode T: 987 Reward: 12.398
# Total T: 191912 Episode Num: 204 Episode T: 560 Reward: 50.829
# Total T: 192911 Episode Num: 205 Episode T: 999 Reward: -88.578
# Total T: 193910 Episode Num: 206 Episode T: 999 Reward: -88.829
# Total T: 194796 Episode Num: 207 Episode T: 886 Reward: 20.368
# ---------------------------------------
# Evaluation over 10 episodes: -99.900
# ---------------------------------------
# Total T: 195182 Episode Num: 208 Episode T: 386 Reward: 65.683
# Total T: 196181 Episode Num: 209 Episode T: 999 Reward: -88.653
# Total T: 197144 Episode Num: 210 Episode T: 963 Reward: 12.187
# Total T: 198143 Episode Num: 211 Episode T: 999 Reward: -90.479
# Total T: 198630 Episode Num: 212 Episode T: 487 Reward: 56.505
# Total T: 199629 Episode Num: 213 Episode T: 999 Reward: -89.369
# ---------------------------------------
# Evaluation over 10 episodes: -99.900
# ---------------------------------------
# Total T: 200628 Episode Num: 214 Episode T: 999 Reward: -90.458
# Total T: 201627 Episode Num: 215 Episode T: 999 Reward: -89.855
# Total T: 202626 Episode Num: 216 Episode T: 999 Reward: -89.810
# Total T: 203625 Episode Num: 217 Episode T: 999 Reward: -90.195
# Total T: 204624 Episode Num: 218 Episode T: 999 Reward: -89.853
# ---------------------------------------
# Evaluation over 10 episodes: -99.898
# ---------------------------------------
# Total T: 205623 Episode Num: 219 Episode T: 999 Reward: -90.614
# Total T: 206622 Episode Num: 220 Episode T: 999 Reward: -90.487
# Total T: 207621 Episode Num: 221 Episode T: 999 Reward: -88.938
# Total T: 208611 Episode Num: 222 Episode T: 990 Reward: 12.309
# Total T: 209610 Episode Num: 223 Episode T: 999 Reward: -89.494
# ---------------------------------------
# Evaluation over 10 episodes: -98.405
# ---------------------------------------
# Total T: 210043 Episode Num: 224 Episode T: 433 Reward: 60.450
# Total T: 211042 Episode Num: 225 Episode T: 999 Reward: -89.517
# Total T: 212041 Episode Num: 226 Episode T: 999 Reward: -88.167
# Total T: 212602 Episode Num: 227 Episode T: 561 Reward: 48.903
# Total T: 213058 Episode Num: 228 Episode T: 456 Reward: 57.746
# Total T: 213544 Episode Num: 229 Episode T: 486 Reward: 56.047
# Total T: 214194 Episode Num: 230 Episode T: 650 Reward: 41.459
# Total T: 214732 Episode Num: 231 Episode T: 538 Reward: 51.445
# ---------------------------------------
# Evaluation over 10 episodes: 88.098
# ---------------------------------------
# Total T: 215297 Episode Num: 232 Episode T: 565 Reward: 48.487
# Total T: 216050 Episode Num: 233 Episode T: 753 Reward: 31.755
# Total T: 217043 Episode Num: 234 Episode T: 993 Reward: 11.800
# Total T: 217572 Episode Num: 235 Episode T: 529 Reward: 53.282
# Total T: 218571 Episode Num: 236 Episode T: 999 Reward: -89.673
# Total T: 219240 Episode Num: 237 Episode T: 669 Reward: 40.090
# ---------------------------------------
# Evaluation over 10 episodes: 74.564
# ---------------------------------------
# Total T: 220239 Episode Num: 238 Episode T: 999 Reward: -89.841
# Total T: 220910 Episode Num: 239 Episode T: 671 Reward: 41.172
# Total T: 221605 Episode Num: 240 Episode T: 695 Reward: 38.242
# Total T: 222604 Episode Num: 241 Episode T: 999 Reward: -88.859
# Total T: 223286 Episode Num: 242 Episode T: 682 Reward: 38.413
# Total T: 223898 Episode Num: 243 Episode T: 612 Reward: 45.584
# Total T: 224897 Episode Num: 244 Episode T: 999 Reward: -88.847
# ---------------------------------------
# Evaluation over 10 episodes: 75.066
# ---------------------------------------
# Total T: 225896 Episode Num: 245 Episode T: 999 Reward: -90.342
# Total T: 226895 Episode Num: 246 Episode T: 999 Reward: -88.205
# Total T: 227894 Episode Num: 247 Episode T: 999 Reward: -89.526
# Total T: 228893 Episode Num: 248 Episode T: 999 Reward: -87.422
# Total T: 229892 Episode Num: 249 Episode T: 999 Reward: -88.472
# ---------------------------------------
# Evaluation over 10 episodes: 89.182
# ---------------------------------------
# Total T: 230374 Episode Num: 250 Episode T: 482 Reward: 56.400
# Total T: 230946 Episode Num: 251 Episode T: 572 Reward: 47.839
# Total T: 231814 Episode Num: 252 Episode T: 868 Reward: 23.036
# Total T: 232493 Episode Num: 253 Episode T: 679 Reward: 39.726
# Total T: 233200 Episode Num: 254 Episode T: 707 Reward: 36.685
# Total T: 233837 Episode Num: 255 Episode T: 637 Reward: 43.226
# Total T: 234232 Episode Num: 256 Episode T: 395 Reward: 64.455
# Total T: 234903 Episode Num: 257 Episode T: 671 Reward: 40.588
# ---------------------------------------
# Evaluation over 10 episodes: 94.503
# ---------------------------------------
# Total T: 235666 Episode Num: 258 Episode T: 763 Reward: 31.548
# Total T: 235992 Episode Num: 259 Episode T: 326 Reward: 70.677
# Total T: 236488 Episode Num: 260 Episode T: 496 Reward: 56.474
# Total T: 237090 Episode Num: 261 Episode T: 602 Reward: 45.551
# Total T: 237765 Episode Num: 262 Episode T: 675 Reward: 40.437
# Total T: 238035 Episode Num: 263 Episode T: 270 Reward: 75.685
# Total T: 238682 Episode Num: 264 Episode T: 647 Reward: 43.885
# Total T: 239196 Episode Num: 265 Episode T: 514 Reward: 54.663
# Total T: 239844 Episode Num: 266 Episode T: 648 Reward: 42.026
# ---------------------------------------
# Evaluation over 10 episodes: 93.720
# ---------------------------------------
# Total T: 240199 Episode Num: 267 Episode T: 355 Reward: 68.057
# Total T: 240605 Episode Num: 268 Episode T: 406 Reward: 62.972
# Total T: 241071 Episode Num: 269 Episode T: 466 Reward: 58.375
# Total T: 241438 Episode Num: 270 Episode T: 367 Reward: 67.300
# Total T: 241928 Episode Num: 271 Episode T: 490 Reward: 56.364
# Total T: 242264 Episode Num: 272 Episode T: 336 Reward: 70.841
# Total T: 243263 Episode Num: 273 Episode T: 999 Reward: -89.669
# Total T: 244046 Episode Num: 274 Episode T: 783 Reward: 29.253
# Total T: 244683 Episode Num: 275 Episode T: 637 Reward: 43.575
# ---------------------------------------
# Evaluation over 10 episodes: 93.777
# ---------------------------------------
# Total T: 245405 Episode Num: 276 Episode T: 722 Reward: 34.593
# Total T: 245732 Episode Num: 277 Episode T: 327 Reward: 70.806
# Total T: 246042 Episode Num: 278 Episode T: 310 Reward: 73.041
# Total T: 246282 Episode Num: 279 Episode T: 240 Reward: 78.453
# Total T: 246737 Episode Num: 280 Episode T: 455 Reward: 59.085
# Total T: 247234 Episode Num: 281 Episode T: 497 Reward: 55.049
# Total T: 247492 Episode Num: 282 Episode T: 258 Reward: 77.150
# Total T: 247842 Episode Num: 283 Episode T: 350 Reward: 68.127
# Total T: 248252 Episode Num: 284 Episode T: 410 Reward: 63.231
# Total T: 248837 Episode Num: 285 Episode T: 585 Reward: 47.963
# Total T: 249086 Episode Num: 286 Episode T: 249 Reward: 77.744
# Total T: 249614 Episode Num: 287 Episode T: 528 Reward: 53.017
# ---------------------------------------
# Evaluation over 10 episodes: 93.404
# ---------------------------------------
# Total T: 250200 Episode Num: 288 Episode T: 586 Reward: 47.599
# Total T: 250880 Episode Num: 289 Episode T: 680 Reward: 38.564
# Total T: 251528 Episode Num: 290 Episode T: 648 Reward: 41.762
# Total T: 251897 Episode Num: 291 Episode T: 369 Reward: 66.555
# Total T: 252097 Episode Num: 292 Episode T: 200 Reward: 81.971
# Total T: 252575 Episode Num: 293 Episode T: 478 Reward: 58.348
# Total T: 253444 Episode Num: 294 Episode T: 869 Reward: 21.209
# Total T: 254443 Episode Num: 295 Episode T: 999 Reward: -90.019
# Total T: 254951 Episode Num: 296 Episode T: 508 Reward: 54.247
# ---------------------------------------
# Evaluation over 10 episodes: 93.188
# ---------------------------------------
# Total T: 255265 Episode Num: 297 Episode T: 314 Reward: 72.050
# Total T: 255812 Episode Num: 298 Episode T: 547 Reward: 52.176
# Total T: 256620 Episode Num: 299 Episode T: 808 Reward: 28.682
# Total T: 256861 Episode Num: 300 Episode T: 241 Reward: 78.445
# Total T: 257374 Episode Num: 301 Episode T: 513 Reward: 52.893
# Total T: 257805 Episode Num: 302 Episode T: 431 Reward: 61.677
# Total T: 258202 Episode Num: 303 Episode T: 397 Reward: 64.494
# Total T: 258599 Episode Num: 304 Episode T: 397 Reward: 63.828
# Total T: 259053 Episode Num: 305 Episode T: 454 Reward: 59.414
# Total T: 259789 Episode Num: 306 Episode T: 736 Reward: 32.979
# ---------------------------------------
# Evaluation over 10 episodes: 93.527
# ---------------------------------------
# Total T: 260191 Episode Num: 307 Episode T: 402 Reward: 64.070
# Total T: 260592 Episode Num: 308 Episode T: 401 Reward: 64.175
# Total T: 260850 Episode Num: 309 Episode T: 258 Reward: 76.936
# Total T: 261652 Episode Num: 310 Episode T: 802 Reward: 27.801
# Total T: 262046 Episode Num: 311 Episode T: 394 Reward: 64.081
# Total T: 262556 Episode Num: 312 Episode T: 510 Reward: 55.198
# Total T: 262939 Episode Num: 313 Episode T: 383 Reward: 66.789
# Total T: 263470 Episode Num: 314 Episode T: 531 Reward: 53.401
# Total T: 264171 Episode Num: 315 Episode T: 701 Reward: 36.825
# Total T: 264830 Episode Num: 316 Episode T: 659 Reward: 40.753
# ---------------------------------------
# Evaluation over 10 episodes: 93.808
# ---------------------------------------
# Total T: 265233 Episode Num: 317 Episode T: 403 Reward: 64.755
# Total T: 265779 Episode Num: 318 Episode T: 546 Reward: 51.300
# Total T: 266652 Episode Num: 319 Episode T: 873 Reward: 21.654
# Total T: 267321 Episode Num: 320 Episode T: 669 Reward: 38.179
# Total T: 267689 Episode Num: 321 Episode T: 368 Reward: 66.353
# Total T: 267907 Episode Num: 322 Episode T: 218 Reward: 80.198
# Total T: 268321 Episode Num: 323 Episode T: 414 Reward: 63.619
# Total T: 269004 Episode Num: 324 Episode T: 683 Reward: 39.158
# Total T: 269422 Episode Num: 325 Episode T: 418 Reward: 62.266
# Total T: 269923 Episode Num: 326 Episode T: 501 Reward: 54.739
# ---------------------------------------
# Evaluation over 10 episodes: 93.737
# ---------------------------------------
# Total T: 270279 Episode Num: 327 Episode T: 356 Reward: 68.437
# Total T: 271022 Episode Num: 328 Episode T: 743 Reward: 33.238
# Total T: 271531 Episode Num: 329 Episode T: 509 Reward: 54.508
# Total T: 272081 Episode Num: 330 Episode T: 550 Reward: 51.313
# Total T: 272531 Episode Num: 331 Episode T: 450 Reward: 59.476
# Total T: 273070 Episode Num: 332 Episode T: 539 Reward: 51.144
# Total T: 273658 Episode Num: 333 Episode T: 588 Reward: 47.127
# Total T: 273977 Episode Num: 334 Episode T: 319 Reward: 70.765
# Total T: 274718 Episode Num: 335 Episode T: 741 Reward: 33.240
# ---------------------------------------
# Evaluation over 10 episodes: 93.717
# ---------------------------------------
# Total T: 275131 Episode Num: 336 Episode T: 413 Reward: 62.861
# Total T: 275727 Episode Num: 337 Episode T: 596 Reward: 47.660
# Total T: 276122 Episode Num: 338 Episode T: 395 Reward: 64.338
# Total T: 276416 Episode Num: 339 Episode T: 294 Reward: 73.631
# Total T: 276946 Episode Num: 340 Episode T: 530 Reward: 52.151
# Total T: 277309 Episode Num: 341 Episode T: 363 Reward: 66.630
# Total T: 278178 Episode Num: 342 Episode T: 869 Reward: 21.292
# Total T: 278736 Episode Num: 343 Episode T: 558 Reward: 50.581
# Total T: 279066 Episode Num: 344 Episode T: 330 Reward: 69.786
# Total T: 279493 Episode Num: 345 Episode T: 427 Reward: 61.505
# ---------------------------------------
# Evaluation over 10 episodes: 93.670
# ---------------------------------------
# Total T: 280399 Episode Num: 346 Episode T: 906 Reward: 16.826
# Total T: 280859 Episode Num: 347 Episode T: 460 Reward: 58.913
# Total T: 281100 Episode Num: 348 Episode T: 241 Reward: 78.550
# Total T: 281779 Episode Num: 349 Episode T: 679 Reward: 39.341
# Total T: 282088 Episode Num: 350 Episode T: 309 Reward: 72.600
# Total T: 282480 Episode Num: 351 Episode T: 392 Reward: 65.587
# Total T: 283137 Episode Num: 352 Episode T: 657 Reward: 41.714
# Total T: 283452 Episode Num: 353 Episode T: 315 Reward: 71.744
# Total T: 284134 Episode Num: 354 Episode T: 682 Reward: 39.521
# Total T: 284682 Episode Num: 355 Episode T: 548 Reward: 50.652
# ---------------------------------------
# Evaluation over 10 episodes: 93.347
# ---------------------------------------
# Total T: 285058 Episode Num: 356 Episode T: 376 Reward: 67.985
# Total T: 285304 Episode Num: 357 Episode T: 246 Reward: 78.363
# Total T: 285726 Episode Num: 358 Episode T: 422 Reward: 61.586
# Total T: 286423 Episode Num: 359 Episode T: 697 Reward: 39.381
# Total T: 286880 Episode Num: 360 Episode T: 457 Reward: 58.850
# Total T: 287475 Episode Num: 361 Episode T: 595 Reward: 46.236
# Total T: 287963 Episode Num: 362 Episode T: 488 Reward: 56.137
# Total T: 288271 Episode Num: 363 Episode T: 308 Reward: 72.370
# Total T: 289270 Episode Num: 364 Episode T: 999 Reward: -89.330
# Total T: 289740 Episode Num: 365 Episode T: 470 Reward: 58.487
# ---------------------------------------
# Evaluation over 10 episodes: 93.210
# ---------------------------------------
# Total T: 290355 Episode Num: 366 Episode T: 615 Reward: 44.981
# Total T: 290958 Episode Num: 367 Episode T: 603 Reward: 47.306
# Total T: 291441 Episode Num: 368 Episode T: 483 Reward: 56.096
# Total T: 292007 Episode Num: 369 Episode T: 566 Reward: 49.211
# Total T: 292370 Episode Num: 370 Episode T: 363 Reward: 67.450
# Total T: 293084 Episode Num: 371 Episode T: 714 Reward: 36.819
# Total T: 293682 Episode Num: 372 Episode T: 598 Reward: 45.305
# Total T: 294108 Episode Num: 373 Episode T: 426 Reward: 61.833
# Total T: 294791 Episode Num: 374 Episode T: 683 Reward: 38.588
# ---------------------------------------
# Evaluation over 10 episodes: 93.236
# ---------------------------------------
# Total T: 295338 Episode Num: 375 Episode T: 547 Reward: 51.439
# Total T: 295791 Episode Num: 376 Episode T: 453 Reward: 58.244
# Total T: 296331 Episode Num: 377 Episode T: 540 Reward: 53.184
# Total T: 297330 Episode Num: 378 Episode T: 999 Reward: -89.919
# Total T: 297739 Episode Num: 379 Episode T: 409 Reward: 64.198
# Total T: 298251 Episode Num: 380 Episode T: 512 Reward: 55.524
# Total T: 299072 Episode Num: 381 Episode T: 821 Reward: 27.006
# Total T: 299784 Episode Num: 382 Episode T: 712 Reward: 36.266
# ---------------------------------------
# Evaluation over 10 episodes: 93.295
# ---------------------------------------
# Total T: 300085 Episode Num: 383 Episode T: 301 Reward: 72.178
# Total T: 300576 Episode Num: 384 Episode T: 491 Reward: 55.876
# Total T: 300940 Episode Num: 385 Episode T: 364 Reward: 67.414
# Total T: 301271 Episode Num: 386 Episode T: 331 Reward: 70.307
# Total T: 302156 Episode Num: 387 Episode T: 885 Reward: 20.557
# Total T: 302514 Episode Num: 388 Episode T: 358 Reward: 68.271
# Total T: 303050 Episode Num: 389 Episode T: 536 Reward: 52.876
# Total T: 303513 Episode Num: 390 Episode T: 463 Reward: 59.069
# Total T: 304047 Episode Num: 391 Episode T: 534 Reward: 52.503
# Total T: 304986 Episode Num: 392 Episode T: 939 Reward: 16.055
# ---------------------------------------
# Evaluation over 10 episodes: 93.265
# ---------------------------------------
# Total T: 305985 Episode Num: 393 Episode T: 999 Reward: -87.912
# Total T: 306616 Episode Num: 394 Episode T: 631 Reward: 42.859
# Total T: 307334 Episode Num: 395 Episode T: 718 Reward: 34.528
# Total T: 308333 Episode Num: 396 Episode T: 999 Reward: -90.207
# Total T: 308991 Episode Num: 397 Episode T: 658 Reward: 38.680
# Total T: 309890 Episode Num: 398 Episode T: 899 Reward: 20.094
# ---------------------------------------
# Evaluation over 10 episodes: 93.074
# ---------------------------------------
# Total T: 310131 Episode Num: 399 Episode T: 241 Reward: 78.361
# Total T: 310735 Episode Num: 400 Episode T: 604 Reward: 46.878
# Total T: 311398 Episode Num: 401 Episode T: 663 Reward: 40.621
# Total T: 312059 Episode Num: 402 Episode T: 661 Reward: 41.377
# Total T: 313058 Episode Num: 403 Episode T: 999 Reward: -88.494
# Total T: 313556 Episode Num: 404 Episode T: 498 Reward: 55.500
# Total T: 314421 Episode Num: 405 Episode T: 865 Reward: 21.260
# Total T: 314892 Episode Num: 406 Episode T: 471 Reward: 57.673
# ---------------------------------------
# Evaluation over 10 episodes: 93.176
# ---------------------------------------
# Total T: 315433 Episode Num: 407 Episode T: 541 Reward: 51.110
# Total T: 315798 Episode Num: 408 Episode T: 365 Reward: 66.970
# Total T: 316245 Episode Num: 409 Episode T: 447 Reward: 60.239
# Total T: 316823 Episode Num: 410 Episode T: 578 Reward: 48.074
# Total T: 317287 Episode Num: 411 Episode T: 464 Reward: 57.898
# Total T: 317610 Episode Num: 412 Episode T: 323 Reward: 70.743
# Total T: 317875 Episode Num: 413 Episode T: 265 Reward: 76.210
# Total T: 318335 Episode Num: 414 Episode T: 460 Reward: 59.562
# Total T: 318510 Episode Num: 415 Episode T: 175 Reward: 84.922
# Total T: 318998 Episode Num: 416 Episode T: 488 Reward: 55.710
# Total T: 319251 Episode Num: 417 Episode T: 253 Reward: 76.384
# Total T: 319782 Episode Num: 418 Episode T: 531 Reward: 54.073
# ---------------------------------------
# Evaluation over 10 episodes: 93.401
# ---------------------------------------
# Total T: 320159 Episode Num: 419 Episode T: 377 Reward: 65.280
# Total T: 320474 Episode Num: 420 Episode T: 315 Reward: 71.287
# Total T: 320782 Episode Num: 421 Episode T: 308 Reward: 71.947
# Total T: 321405 Episode Num: 422 Episode T: 623 Reward: 44.105
# Total T: 321828 Episode Num: 423 Episode T: 423 Reward: 61.699
# Total T: 322465 Episode Num: 424 Episode T: 637 Reward: 42.554
# Total T: 322682 Episode Num: 425 Episode T: 217 Reward: 80.452
# Total T: 323589 Episode Num: 426 Episode T: 907 Reward: 18.315
# Total T: 324183 Episode Num: 427 Episode T: 594 Reward: 47.033
# Total T: 324665 Episode Num: 428 Episode T: 482 Reward: 56.176
# Total T: 324940 Episode Num: 429 Episode T: 275 Reward: 75.796
# ---------------------------------------
# Evaluation over 10 episodes: 92.819
# ---------------------------------------
# Total T: 325546 Episode Num: 430 Episode T: 606 Reward: 46.420
# Total T: 325967 Episode Num: 431 Episode T: 421 Reward: 62.379
# Total T: 326279 Episode Num: 432 Episode T: 312 Reward: 71.770
# Total T: 326580 Episode Num: 433 Episode T: 301 Reward: 73.556
# Total T: 326883 Episode Num: 434 Episode T: 303 Reward: 73.388
# Total T: 327210 Episode Num: 435 Episode T: 327 Reward: 70.485
# Total T: 327554 Episode Num: 436 Episode T: 344 Reward: 69.304
# Total T: 327871 Episode Num: 437 Episode T: 317 Reward: 71.092
# Total T: 328378 Episode Num: 438 Episode T: 507 Reward: 55.314
# Total T: 328967 Episode Num: 439 Episode T: 589 Reward: 46.762
# Total T: 329338 Episode Num: 440 Episode T: 371 Reward: 66.131
# ---------------------------------------
# Evaluation over 10 episodes: 90.583
# ---------------------------------------
# Total T: 330008 Episode Num: 441 Episode T: 670 Reward: 38.880
# Total T: 330407 Episode Num: 442 Episode T: 399 Reward: 63.901
# Total T: 331001 Episode Num: 443 Episode T: 594 Reward: 46.304
# Total T: 331187 Episode Num: 444 Episode T: 186 Reward: 83.854
# Total T: 331512 Episode Num: 445 Episode T: 325 Reward: 69.943
# Total T: 332112 Episode Num: 446 Episode T: 600 Reward: 46.528
# Total T: 332511 Episode Num: 447 Episode T: 399 Reward: 64.778
# Total T: 332806 Episode Num: 448 Episode T: 295 Reward: 72.768
# Total T: 333358 Episode Num: 449 Episode T: 552 Reward: 50.312
# Total T: 333565 Episode Num: 450 Episode T: 207 Reward: 80.798
# Total T: 333903 Episode Num: 451 Episode T: 338 Reward: 69.076
# Total T: 334743 Episode Num: 452 Episode T: 840 Reward: 24.805
# ---------------------------------------
# Evaluation over 10 episodes: 91.507
# ---------------------------------------
# Total T: 335403 Episode Num: 453 Episode T: 660 Reward: 40.549
# Total T: 336103 Episode Num: 454 Episode T: 700 Reward: 36.450
# Total T: 336447 Episode Num: 455 Episode T: 344 Reward: 69.259
# Total T: 336850 Episode Num: 456 Episode T: 403 Reward: 64.020
# Total T: 337438 Episode Num: 457 Episode T: 588 Reward: 47.293
# Total T: 337753 Episode Num: 458 Episode T: 315 Reward: 71.570
# Total T: 338469 Episode Num: 459 Episode T: 716 Reward: 35.145
# Total T: 338786 Episode Num: 460 Episode T: 317 Reward: 71.648
# Total T: 339295 Episode Num: 461 Episode T: 509 Reward: 54.518
# ---------------------------------------
# Evaluation over 10 episodes: 92.581
# ---------------------------------------
# Total T: 340294 Episode Num: 462 Episode T: 999 Reward: -90.400
# Total T: 340605 Episode Num: 463 Episode T: 311 Reward: 72.040
# Total T: 341210 Episode Num: 464 Episode T: 605 Reward: 46.286
# Total T: 341462 Episode Num: 465 Episode T: 252 Reward: 77.484
# Total T: 341892 Episode Num: 466 Episode T: 430 Reward: 61.748
# Total T: 342383 Episode Num: 467 Episode T: 491 Reward: 57.487
# Total T: 342876 Episode Num: 468 Episode T: 493 Reward: 55.783
# Total T: 343330 Episode Num: 469 Episode T: 454 Reward: 59.619
# Total T: 343852 Episode Num: 470 Episode T: 522 Reward: 53.120
# Total T: 344153 Episode Num: 471 Episode T: 301 Reward: 73.392
# Total T: 344498 Episode Num: 472 Episode T: 345 Reward: 70.141
# Total T: 344759 Episode Num: 473 Episode T: 261 Reward: 76.864
# ---------------------------------------
# Evaluation over 10 episodes: 92.623
# ---------------------------------------
# Total T: 345217 Episode Num: 474 Episode T: 458 Reward: 58.653
# Total T: 346081 Episode Num: 475 Episode T: 864 Reward: 23.331
# Total T: 346495 Episode Num: 476 Episode T: 414 Reward: 61.638
# Total T: 346939 Episode Num: 477 Episode T: 444 Reward: 60.873
# Total T: 347581 Episode Num: 478 Episode T: 642 Reward: 41.274
# Total T: 348099 Episode Num: 479 Episode T: 518 Reward: 54.037
# Total T: 348561 Episode Num: 480 Episode T: 462 Reward: 58.574
# Total T: 348804 Episode Num: 481 Episode T: 243 Reward: 78.348
# Total T: 349288 Episode Num: 482 Episode T: 484 Reward: 57.712
# Total T: 349799 Episode Num: 483 Episode T: 511 Reward: 56.175
# ---------------------------------------
# Evaluation over 10 episodes: 92.998
# ---------------------------------------
# Total T: 350127 Episode Num: 484 Episode T: 328 Reward: 70.686
# Total T: 350457 Episode Num: 485 Episode T: 330 Reward: 71.118
# Total T: 351016 Episode Num: 486 Episode T: 559 Reward: 49.155
# Total T: 351978 Episode Num: 487 Episode T: 962 Reward: 13.415
# Total T: 352289 Episode Num: 488 Episode T: 311 Reward: 72.456
# Total T: 352724 Episode Num: 489 Episode T: 435 Reward: 61.535
# Total T: 353108 Episode Num: 490 Episode T: 384 Reward: 65.266
# Total T: 353670 Episode Num: 491 Episode T: 562 Reward: 49.059
# Total T: 354246 Episode Num: 492 Episode T: 576 Reward: 48.181
# Total T: 354656 Episode Num: 493 Episode T: 410 Reward: 62.468
# ---------------------------------------
# Evaluation over 10 episodes: 93.326
# ---------------------------------------
# Total T: 355140 Episode Num: 494 Episode T: 484 Reward: 56.174
# Total T: 355883 Episode Num: 495 Episode T: 743 Reward: 32.782
# Total T: 356631 Episode Num: 496 Episode T: 748 Reward: 31.619
# Total T: 357046 Episode Num: 497 Episode T: 415 Reward: 62.226
# Total T: 357869 Episode Num: 498 Episode T: 823 Reward: 26.449
# Total T: 358184 Episode Num: 499 Episode T: 315 Reward: 72.227
# Total T: 358580 Episode Num: 500 Episode T: 396 Reward: 64.080
# Total T: 358925 Episode Num: 501 Episode T: 345 Reward: 69.103
# Total T: 359325 Episode Num: 502 Episode T: 400 Reward: 63.597
# Total T: 359640 Episode Num: 503 Episode T: 315 Reward: 72.433
# ---------------------------------------
# Evaluation over 10 episodes: 92.946
# ---------------------------------------
# Total T: 360126 Episode Num: 504 Episode T: 486 Reward: 56.712
# Total T: 360621 Episode Num: 505 Episode T: 495 Reward: 55.270
# Total T: 361269 Episode Num: 506 Episode T: 648 Reward: 41.489
# Total T: 361713 Episode Num: 507 Episode T: 444 Reward: 60.365
# Total T: 361962 Episode Num: 508 Episode T: 249 Reward: 77.111
# Total T: 362386 Episode Num: 509 Episode T: 424 Reward: 62.513
# Total T: 362729 Episode Num: 510 Episode T: 343 Reward: 70.323
# Total T: 363396 Episode Num: 511 Episode T: 667 Reward: 40.433
# Total T: 364086 Episode Num: 512 Episode T: 690 Reward: 39.375
# Total T: 364574 Episode Num: 513 Episode T: 488 Reward: 56.598
# ---------------------------------------
# Evaluation over 10 episodes: 90.972
# ---------------------------------------
# Total T: 365150 Episode Num: 514 Episode T: 576 Reward: 49.143
# Total T: 365723 Episode Num: 515 Episode T: 573 Reward: 48.187
# Total T: 366695 Episode Num: 516 Episode T: 972 Reward: 13.033
# Total T: 367086 Episode Num: 517 Episode T: 391 Reward: 65.195
# Total T: 367595 Episode Num: 518 Episode T: 509 Reward: 55.399
# Total T: 367996 Episode Num: 519 Episode T: 401 Reward: 64.642
# Total T: 368519 Episode Num: 520 Episode T: 523 Reward: 53.868
# Total T: 368820 Episode Num: 521 Episode T: 301 Reward: 73.407
# Total T: 369191 Episode Num: 522 Episode T: 371 Reward: 66.195
# Total T: 369483 Episode Num: 523 Episode T: 292 Reward: 73.641
# ---------------------------------------
# Evaluation over 10 episodes: 92.230
# ---------------------------------------
# Total T: 370190 Episode Num: 524 Episode T: 707 Reward: 35.827
# Total T: 370515 Episode Num: 525 Episode T: 325 Reward: 70.848
# Total T: 370760 Episode Num: 526 Episode T: 245 Reward: 78.688
# Total T: 371591 Episode Num: 527 Episode T: 831 Reward: 25.107
# Total T: 372021 Episode Num: 528 Episode T: 430 Reward: 61.546
# Total T: 372487 Episode Num: 529 Episode T: 466 Reward: 58.486
# Total T: 372958 Episode Num: 530 Episode T: 471 Reward: 57.551
# Total T: 373396 Episode Num: 531 Episode T: 438 Reward: 60.162
# Total T: 374075 Episode Num: 532 Episode T: 679 Reward: 39.787
# Total T: 374540 Episode Num: 533 Episode T: 465 Reward: 58.322
# Total T: 374957 Episode Num: 534 Episode T: 417 Reward: 63.381
# ---------------------------------------
# Evaluation over 10 episodes: 92.357
# ---------------------------------------
# Total T: 375495 Episode Num: 535 Episode T: 538 Reward: 52.126
# Total T: 375783 Episode Num: 536 Episode T: 288 Reward: 74.903
# Total T: 376134 Episode Num: 537 Episode T: 351 Reward: 68.376
# Total T: 376413 Episode Num: 538 Episode T: 279 Reward: 75.160
# Total T: 376997 Episode Num: 539 Episode T: 584 Reward: 48.340
# Total T: 377389 Episode Num: 540 Episode T: 392 Reward: 63.970
# Total T: 377879 Episode Num: 541 Episode T: 490 Reward: 56.792
# Total T: 378466 Episode Num: 542 Episode T: 587 Reward: 46.645
# Total T: 378776 Episode Num: 543 Episode T: 310 Reward: 72.449
# Total T: 379532 Episode Num: 544 Episode T: 756 Reward: 30.845
# ---------------------------------------
# Evaluation over 10 episodes: 92.457
# ---------------------------------------
# Total T: 380299 Episode Num: 545 Episode T: 767 Reward: 31.762
# Total T: 380911 Episode Num: 546 Episode T: 612 Reward: 45.067
# Total T: 381144 Episode Num: 547 Episode T: 233 Reward: 79.434
# Total T: 381540 Episode Num: 548 Episode T: 396 Reward: 63.946
# Total T: 382222 Episode Num: 549 Episode T: 682 Reward: 39.427
# Total T: 382649 Episode Num: 550 Episode T: 427 Reward: 61.611
# Total T: 383188 Episode Num: 551 Episode T: 539 Reward: 52.043
# Total T: 383952 Episode Num: 552 Episode T: 764 Reward: 31.781
# Total T: 384349 Episode Num: 553 Episode T: 397 Reward: 64.207
# Total T: 384761 Episode Num: 554 Episode T: 412 Reward: 62.624
# ---------------------------------------
# Evaluation over 10 episodes: 92.180
# ---------------------------------------
# Total T: 385521 Episode Num: 555 Episode T: 760 Reward: 33.005
# Total T: 386236 Episode Num: 556 Episode T: 715 Reward: 36.515
# Total T: 386556 Episode Num: 557 Episode T: 320 Reward: 70.907
# Total T: 387053 Episode Num: 558 Episode T: 497 Reward: 55.157
# Total T: 387645 Episode Num: 559 Episode T: 592 Reward: 47.303
# Total T: 387987 Episode Num: 560 Episode T: 342 Reward: 68.883
# Total T: 388610 Episode Num: 561 Episode T: 623 Reward: 44.545
# Total T: 389016 Episode Num: 562 Episode T: 406 Reward: 63.839
# Total T: 389307 Episode Num: 563 Episode T: 291 Reward: 74.457
# Total T: 389863 Episode Num: 564 Episode T: 556 Reward: 49.868
# ---------------------------------------
# Evaluation over 10 episodes: 92.630
# ---------------------------------------
# Total T: 390391 Episode Num: 565 Episode T: 528 Reward: 52.370
# Total T: 390654 Episode Num: 566 Episode T: 263 Reward: 76.561
# Total T: 391043 Episode Num: 567 Episode T: 389 Reward: 65.119
# Total T: 391423 Episode Num: 568 Episode T: 380 Reward: 65.919
# Total T: 391798 Episode Num: 569 Episode T: 375 Reward: 66.302
# Total T: 392182 Episode Num: 570 Episode T: 384 Reward: 65.726
# Total T: 392455 Episode Num: 571 Episode T: 273 Reward: 75.588
# Total T: 392847 Episode Num: 572 Episode T: 392 Reward: 64.539
# Total T: 393173 Episode Num: 573 Episode T: 326 Reward: 70.545
# Total T: 393509 Episode Num: 574 Episode T: 336 Reward: 69.547
# Total T: 393859 Episode Num: 575 Episode T: 350 Reward: 68.073
# Total T: 394330 Episode Num: 576 Episode T: 471 Reward: 58.391
# Total T: 394692 Episode Num: 577 Episode T: 362 Reward: 67.454
# ---------------------------------------
# Evaluation over 10 episodes: 92.832
# ---------------------------------------
# Total T: 395161 Episode Num: 578 Episode T: 469 Reward: 58.343
# Total T: 395580 Episode Num: 579 Episode T: 419 Reward: 62.590
# ...
# Total T: 897482 Episode Num: 1640 Episode T: 428 Reward: 62.173
# Total T: 898219 Episode Num: 1641 Episode T: 737 Reward: 33.714
# Total T: 898806 Episode Num: 1642 Episode T: 587 Reward: 47.875
# Total T: 899213 Episode Num: 1643 Episode T: 407 Reward: 63.350
# Total T: 899781 Episode Num: 1644 Episode T: 568 Reward: 49.178
# ---------------------------------------
# Evaluation over 10 episodes: 92.353
# ---------------------------------------
# Total T: 900115 Episode Num: 1645 Episode T: 334 Reward: 69.779
# Total T: 900850 Episode Num: 1646 Episode T: 735 Reward: 32.903
# Total T: 901242 Episode Num: 1647 Episode T: 392 Reward: 65.064
# Total T: 901501 Episode Num: 1648 Episode T: 259 Reward: 76.466
# Total T: 902091 Episode Num: 1649 Episode T: 590 Reward: 47.117
# Total T: 903044 Episode Num: 1650 Episode T: 953 Reward: 14.734
# Total T: 903364 Episode Num: 1651 Episode T: 320 Reward: 71.838
# Total T: 904073 Episode Num: 1652 Episode T: 709 Reward: 36.923
# Total T: 904584 Episode Num: 1653 Episode T: 511 Reward: 54.091
# ---------------------------------------
# Evaluation over 10 episodes: 92.177
# ---------------------------------------
# Total T: 905479 Episode Num: 1654 Episode T: 895 Reward: 20.964
# Total T: 905771 Episode Num: 1655 Episode T: 292 Reward: 73.746
# Total T: 906107 Episode Num: 1656 Episode T: 336 Reward: 70.067
# Total T: 906465 Episode Num: 1657 Episode T: 358 Reward: 68.276
# Total T: 906886 Episode Num: 1658 Episode T: 421 Reward: 62.080
# Total T: 907437 Episode Num: 1659 Episode T: 551 Reward: 50.113
# Total T: 907705 Episode Num: 1660 Episode T: 268 Reward: 76.512
# Total T: 907948 Episode Num: 1661 Episode T: 243 Reward: 78.537
# Total T: 908345 Episode Num: 1662 Episode T: 397 Reward: 63.425
# Total T: 908904 Episode Num: 1663 Episode T: 559 Reward: 49.870
# Total T: 909141 Episode Num: 1664 Episode T: 237 Reward: 78.659
# Total T: 909480 Episode Num: 1665 Episode T: 339 Reward: 69.488
# Total T: 909839 Episode Num: 1666 Episode T: 359 Reward: 67.250
# ---------------------------------------
# Evaluation over 10 episodes: 92.211
# ---------------------------------------
# Total T: 910094 Episode Num: 1667 Episode T: 255 Reward: 77.768
# Total T: 910508 Episode Num: 1668 Episode T: 414 Reward: 63.945
# Total T: 910750 Episode Num: 1669 Episode T: 242 Reward: 78.465
# Total T: 911588 Episode Num: 1670 Episode T: 838 Reward: 24.933
# Total T: 911955 Episode Num: 1671 Episode T: 367 Reward: 68.194
# Total T: 912615 Episode Num: 1672 Episode T: 660 Reward: 41.545
# Total T: 913172 Episode Num: 1673 Episode T: 557 Reward: 50.285
# Total T: 913641 Episode Num: 1674 Episode T: 469 Reward: 57.725
# Total T: 914136 Episode Num: 1675 Episode T: 495 Reward: 56.618
# Total T: 914669 Episode Num: 1676 Episode T: 533 Reward: 52.929
# ---------------------------------------
# Evaluation over 10 episodes: 92.565
# ---------------------------------------
# Total T: 915106 Episode Num: 1677 Episode T: 437 Reward: 60.517
# Total T: 915602 Episode Num: 1678 Episode T: 496 Reward: 55.216
# Total T: 916198 Episode Num: 1679 Episode T: 596 Reward: 47.827
# Total T: 916668 Episode Num: 1680 Episode T: 470 Reward: 58.531
# Total T: 917187 Episode Num: 1681 Episode T: 519 Reward: 53.596
# Total T: 917527 Episode Num: 1682 Episode T: 340 Reward: 68.986
# Total T: 917876 Episode Num: 1683 Episode T: 349 Reward: 69.149
# Total T: 918074 Episode Num: 1684 Episode T: 198 Reward: 82.221
# Total T: 918483 Episode Num: 1685 Episode T: 409 Reward: 63.810
# Total T: 918703 Episode Num: 1686 Episode T: 220 Reward: 80.447
# Total T: 918996 Episode Num: 1687 Episode T: 293 Reward: 73.851
# Total T: 919410 Episode Num: 1688 Episode T: 414 Reward: 63.020
# Total T: 919812 Episode Num: 1689 Episode T: 402 Reward: 65.037
# ---------------------------------------
# Evaluation over 10 episodes: 92.671
# ---------------------------------------
# Total T: 920114 Episode Num: 1690 Episode T: 302 Reward: 73.420
# Total T: 920441 Episode Num: 1691 Episode T: 327 Reward: 70.605
# Total T: 920694 Episode Num: 1692 Episode T: 253 Reward: 76.559
# Total T: 921046 Episode Num: 1693 Episode T: 352 Reward: 68.226
# Total T: 921421 Episode Num: 1694 Episode T: 375 Reward: 64.969
# Total T: 922227 Episode Num: 1695 Episode T: 806 Reward: 27.944
# Total T: 922549 Episode Num: 1696 Episode T: 322 Reward: 71.766
# Total T: 923548 Episode Num: 1697 Episode T: 999 Reward: -88.710
# Total T: 923967 Episode Num: 1698 Episode T: 419 Reward: 62.442
# Total T: 924530 Episode Num: 1699 Episode T: 563 Reward: 50.002
# ---------------------------------------
# Evaluation over 10 episodes: 92.766
# ---------------------------------------
# Total T: 925171 Episode Num: 1700 Episode T: 641 Reward: 43.439
# Total T: 925756 Episode Num: 1701 Episode T: 585 Reward: 47.774
# Total T: 926548 Episode Num: 1702 Episode T: 792 Reward: 29.661
# Total T: 926802 Episode Num: 1703 Episode T: 254 Reward: 77.610
# Total T: 927256 Episode Num: 1704 Episode T: 454 Reward: 59.704
# Total T: 928223 Episode Num: 1705 Episode T: 967 Reward: 14.035
# Total T: 929058 Episode Num: 1706 Episode T: 835 Reward: 25.074
# ---------------------------------------
# Evaluation over 10 episodes: 92.941
# ---------------------------------------
# Total T: 930057 Episode Num: 1707 Episode T: 999 Reward: -88.118
# Total T: 930287 Episode Num: 1708 Episode T: 230 Reward: 78.929
# Total T: 930566 Episode Num: 1709 Episode T: 279 Reward: 74.251
# Total T: 930946 Episode Num: 1710 Episode T: 380 Reward: 65.742
# Total T: 931287 Episode Num: 1711 Episode T: 341 Reward: 69.123
# Total T: 931754 Episode Num: 1712 Episode T: 467 Reward: 56.583
# Total T: 932311 Episode Num: 1713 Episode T: 557 Reward: 50.764
# Total T: 932941 Episode Num: 1714 Episode T: 630 Reward: 43.189
# Total T: 933492 Episode Num: 1715 Episode T: 551 Reward: 49.519
# Total T: 934138 Episode Num: 1716 Episode T: 646 Reward: 42.964
# Total T: 934708 Episode Num: 1717 Episode T: 570 Reward: 50.308
# ---------------------------------------
# Evaluation over 10 episodes: 92.984
# ---------------------------------------
# Total T: 935014 Episode Num: 1718 Episode T: 306 Reward: 72.496
# Total T: 935335 Episode Num: 1719 Episode T: 321 Reward: 71.706
# Total T: 935572 Episode Num: 1720 Episode T: 237 Reward: 78.193
# Total T: 936056 Episode Num: 1721 Episode T: 484 Reward: 56.253
# Total T: 936756 Episode Num: 1722 Episode T: 700 Reward: 38.256
# Total T: 937755 Episode Num: 1723 Episode T: 999 Reward: -89.116
# Total T: 938203 Episode Num: 1724 Episode T: 448 Reward: 59.324
# Total T: 938471 Episode Num: 1725 Episode T: 268 Reward: 76.489
# Total T: 938792 Episode Num: 1726 Episode T: 321 Reward: 72.071
# Total T: 939224 Episode Num: 1727 Episode T: 432 Reward: 60.985
# Total T: 939629 Episode Num: 1728 Episode T: 405 Reward: 64.894
# ---------------------------------------
# Evaluation over 10 episodes: 92.833
# ---------------------------------------
# Total T: 940390 Episode Num: 1729 Episode T: 761 Reward: 31.312
# Total T: 941139 Episode Num: 1730 Episode T: 749 Reward: 34.133
# Total T: 941451 Episode Num: 1731 Episode T: 312 Reward: 71.748
# Total T: 941995 Episode Num: 1732 Episode T: 544 Reward: 52.491
# Total T: 942389 Episode Num: 1733 Episode T: 394 Reward: 64.955
# Total T: 942701 Episode Num: 1734 Episode T: 312 Reward: 71.936
# Total T: 943456 Episode Num: 1735 Episode T: 755 Reward: 32.542
# Total T: 943711 Episode Num: 1736 Episode T: 255 Reward: 77.061
# Total T: 944200 Episode Num: 1737 Episode T: 489 Reward: 56.908
# Total T: 944672 Episode Num: 1738 Episode T: 472 Reward: 57.618
# ---------------------------------------
# Evaluation over 10 episodes: 93.031
# ---------------------------------------
# Total T: 945184 Episode Num: 1739 Episode T: 512 Reward: 53.777
# Total T: 945632 Episode Num: 1740 Episode T: 448 Reward: 59.996
# Total T: 946316 Episode Num: 1741 Episode T: 684 Reward: 38.312
# Total T: 946996 Episode Num: 1742 Episode T: 680 Reward: 39.248
# Total T: 947623 Episode Num: 1743 Episode T: 627 Reward: 42.508
# Total T: 947861 Episode Num: 1744 Episode T: 238 Reward: 78.148
# Total T: 948860 Episode Num: 1745 Episode T: 999 Reward: -89.285
# Total T: 949105 Episode Num: 1746 Episode T: 245 Reward: 78.109
# Total T: 949723 Episode Num: 1747 Episode T: 618 Reward: 44.888
# ---------------------------------------
# Evaluation over 10 episodes: 93.202
# ---------------------------------------
# Total T: 950076 Episode Num: 1748 Episode T: 353 Reward: 67.957
# Total T: 950346 Episode Num: 1749 Episode T: 270 Reward: 75.362
# Total T: 950991 Episode Num: 1750 Episode T: 645 Reward: 43.005
# Total T: 951443 Episode Num: 1751 Episode T: 452 Reward: 59.477
# Total T: 951785 Episode Num: 1752 Episode T: 342 Reward: 68.632
# Total T: 952309 Episode Num: 1753 Episode T: 524 Reward: 53.338
# Total T: 952650 Episode Num: 1754 Episode T: 341 Reward: 69.597
# Total T: 953085 Episode Num: 1755 Episode T: 435 Reward: 60.980
# Total T: 953474 Episode Num: 1756 Episode T: 389 Reward: 64.934
# Total T: 954473 Episode Num: 1757 Episode T: 999 Reward: -89.170
# ---------------------------------------
# Evaluation over 10 episodes: 93.188
# ---------------------------------------
# Total T: 955256 Episode Num: 1758 Episode T: 783 Reward: 31.495
# Total T: 955859 Episode Num: 1759 Episode T: 603 Reward: 45.815
# Total T: 956373 Episode Num: 1760 Episode T: 514 Reward: 53.939
# Total T: 956605 Episode Num: 1761 Episode T: 232 Reward: 78.739
# Total T: 956971 Episode Num: 1762 Episode T: 366 Reward: 67.130
# Total T: 957411 Episode Num: 1763 Episode T: 440 Reward: 59.822
# Total T: 958023 Episode Num: 1764 Episode T: 612 Reward: 44.437
# Total T: 958341 Episode Num: 1765 Episode T: 318 Reward: 71.046
# Total T: 958580 Episode Num: 1766 Episode T: 239 Reward: 78.898
# Total T: 959030 Episode Num: 1767 Episode T: 450 Reward: 59.665
# Total T: 959425 Episode Num: 1768 Episode T: 395 Reward: 64.772
# Total T: 959721 Episode Num: 1769 Episode T: 296 Reward: 74.132
# ---------------------------------------
# Evaluation over 10 episodes: 93.179
# ---------------------------------------
# Total T: 960095 Episode Num: 1770 Episode T: 374 Reward: 66.470
# Total T: 960373 Episode Num: 1771 Episode T: 278 Reward: 75.359
# Total T: 960742 Episode Num: 1772 Episode T: 369 Reward: 67.495
# Total T: 961518 Episode Num: 1773 Episode T: 776 Reward: 29.602
# Total T: 962055 Episode Num: 1774 Episode T: 537 Reward: 51.756
# Total T: 962456 Episode Num: 1775 Episode T: 401 Reward: 63.765
# Total T: 963146 Episode Num: 1776 Episode T: 690 Reward: 37.959
# Total T: 963387 Episode Num: 1777 Episode T: 241 Reward: 78.185
# Total T: 963915 Episode Num: 1778 Episode T: 528 Reward: 52.555
# Total T: 964324 Episode Num: 1779 Episode T: 409 Reward: 62.983
# Total T: 964844 Episode Num: 1780 Episode T: 520 Reward: 53.928
# ---------------------------------------
# Evaluation over 10 episodes: 93.186
# ---------------------------------------
# Total T: 965365 Episode Num: 1781 Episode T: 521 Reward: 54.240
# Total T: 965904 Episode Num: 1782 Episode T: 539 Reward: 51.724
# Total T: 966507 Episode Num: 1783 Episode T: 603 Reward: 45.076
# Total T: 967110 Episode Num: 1784 Episode T: 603 Reward: 44.743
# Total T: 967381 Episode Num: 1785 Episode T: 271 Reward: 75.698
# Total T: 968150 Episode Num: 1786 Episode T: 769 Reward: 31.461
# Total T: 968497 Episode Num: 1787 Episode T: 347 Reward: 68.763
# Total T: 968842 Episode Num: 1788 Episode T: 345 Reward: 68.478
# Total T: 969193 Episode Num: 1789 Episode T: 351 Reward: 68.919
# Total T: 969541 Episode Num: 1790 Episode T: 348 Reward: 68.026
# ---------------------------------------
# Evaluation over 10 episodes: 93.110
# ---------------------------------------
# Total T: 970540 Episode Num: 1791 Episode T: 999 Reward: -89.123
# Total T: 971356 Episode Num: 1792 Episode T: 816 Reward: 27.303
# Total T: 971693 Episode Num: 1793 Episode T: 337 Reward: 71.180
# Total T: 972150 Episode Num: 1794 Episode T: 457 Reward: 59.397
# Total T: 972604 Episode Num: 1795 Episode T: 454 Reward: 58.749
# Total T: 972885 Episode Num: 1796 Episode T: 281 Reward: 75.344
# Total T: 973154 Episode Num: 1797 Episode T: 269 Reward: 75.558
# Total T: 973536 Episode Num: 1798 Episode T: 382 Reward: 66.274
# Total T: 973938 Episode Num: 1799 Episode T: 402 Reward: 64.212
# Total T: 974179 Episode Num: 1800 Episode T: 241 Reward: 78.178
# Total T: 974712 Episode Num: 1801 Episode T: 533 Reward: 51.865
# ---------------------------------------
# Evaluation over 10 episodes: 93.044
# ---------------------------------------
# Total T: 975486 Episode Num: 1802 Episode T: 774 Reward: 31.335
# Total T: 975989 Episode Num: 1803 Episode T: 503 Reward: 54.950
# Total T: 976377 Episode Num: 1804 Episode T: 388 Reward: 64.726
# Total T: 976781 Episode Num: 1805 Episode T: 404 Reward: 63.464
# Total T: 977713 Episode Num: 1806 Episode T: 932 Reward: 15.191
# Total T: 978193 Episode Num: 1807 Episode T: 480 Reward: 57.807
# Total T: 978795 Episode Num: 1808 Episode T: 602 Reward: 47.206
# Total T: 979150 Episode Num: 1809 Episode T: 355 Reward: 68.663
# Total T: 979839 Episode Num: 1810 Episode T: 689 Reward: 38.074
# ---------------------------------------
# Evaluation over 10 episodes: 93.025
# ---------------------------------------
# Total T: 980363 Episode Num: 1811 Episode T: 524 Reward: 52.420
# Total T: 980915 Episode Num: 1812 Episode T: 552 Reward: 51.707
# Total T: 981601 Episode Num: 1813 Episode T: 686 Reward: 38.838
# Total T: 981881 Episode Num: 1814 Episode T: 280 Reward: 75.179
# Total T: 982220 Episode Num: 1815 Episode T: 339 Reward: 71.022
# Total T: 983050 Episode Num: 1816 Episode T: 830 Reward: 24.677
# Total T: 983401 Episode Num: 1817 Episode T: 351 Reward: 68.764
# Total T: 984074 Episode Num: 1818 Episode T: 673 Reward: 39.066
# Total T: 984469 Episode Num: 1819 Episode T: 395 Reward: 63.389
# ---------------------------------------
# Evaluation over 10 episodes: 93.108
# ---------------------------------------
# Total T: 985148 Episode Num: 1820 Episode T: 679 Reward: 39.218
# Total T: 985528 Episode Num: 1821 Episode T: 380 Reward: 66.303
# Total T: 986050 Episode Num: 1822 Episode T: 522 Reward: 53.585
# Total T: 986816 Episode Num: 1823 Episode T: 766 Reward: 31.726
# Total T: 987517 Episode Num: 1824 Episode T: 701 Reward: 37.186
# Total T: 988030 Episode Num: 1825 Episode T: 513 Reward: 54.108
# Total T: 988535 Episode Num: 1826 Episode T: 505 Reward: 54.942
# Total T: 989122 Episode Num: 1827 Episode T: 587 Reward: 47.716
# Total T: 989411 Episode Num: 1828 Episode T: 289 Reward: 73.589
# Total T: 989651 Episode Num: 1829 Episode T: 240 Reward: 78.266
# ---------------------------------------
# Evaluation over 10 episodes: 93.139
# ---------------------------------------
# Total T: 990150 Episode Num: 1830 Episode T: 499 Reward: 55.732
# Total T: 991149 Episode Num: 1831 Episode T: 999 Reward: -87.942
# Total T: 991569 Episode Num: 1832 Episode T: 420 Reward: 61.856
# Total T: 991784 Episode Num: 1833 Episode T: 215 Reward: 80.429
# Total T: 992101 Episode Num: 1834 Episode T: 317 Reward: 71.743
# Total T: 992814 Episode Num: 1835 Episode T: 713 Reward: 35.610
# Total T: 993257 Episode Num: 1836 Episode T: 443 Reward: 61.075
# Total T: 993670 Episode Num: 1837 Episode T: 413 Reward: 63.083
# Total T: 994039 Episode Num: 1838 Episode T: 369 Reward: 67.417
# Total T: 994336 Episode Num: 1839 Episode T: 297 Reward: 73.903
# Total T: 994790 Episode Num: 1840 Episode T: 454 Reward: 59.830
# ---------------------------------------
# Evaluation over 10 episodes: 93.138
# ---------------------------------------
# Total T: 995514 Episode Num: 1841 Episode T: 724 Reward: 34.126
# Total T: 995789 Episode Num: 1842 Episode T: 275 Reward: 74.868
# Total T: 996576 Episode Num: 1843 Episode T: 787 Reward: 28.111
# Total T: 997150 Episode Num: 1844 Episode T: 574 Reward: 48.901
# Total T: 997327 Episode Num: 1845 Episode T: 177 Reward: 84.179
# Total T: 997715 Episode Num: 1846 Episode T: 388 Reward: 65.537
# Total T: 998508 Episode Num: 1847 Episode T: 793 Reward: 28.854
# Total T: 999334 Episode Num: 1848 Episode T: 826 Reward: 26.829
# Total T: 999632 Episode Num: 1849 Episode T: 298 Reward: 73.954
# Total T: 999987 Episode Num: 1850 Episode T: 355 Reward: 67.259
# ---------------------------------------
# Evaluation over 10 episodes: 93.138
# ---------------------------------------

# %%
# Visualization


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the continuous version of the Mountain Car environment
env = gym.make("MountainCarContinuous-v0", render_mode="human")

# Reset the environment and prepare the initial state
state, _ = env.reset()
state = torch.tensor(state, device=device).float().unsqueeze(0)

# Initialize variables to track episodes and scores
ep_count = 0
current_ep_reward = 0
scores = []

# Run simulation for 50 episodes
while ep_count < 50:
    env.render()
    action = act(state, 0)  # Ensure this function now returns a continuous action
    state, reward, terminated, truncated, _ = env.step([action.item()])  # Execute action, note the list around action.item()

    state = torch.tensor(state, device=device).float().unsqueeze(0)
    current_ep_reward += reward
    done = terminated or truncated
    
    if done:
        ep_count += 1
        scores.append(current_ep_reward)
        current_ep_reward = 0
        state, _ = env.reset()  # Reset for the next episode
        state = torch.tensor(state, device=device).float().unsqueeze(0)

env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 22
#      20 while ep_count < 50:
#      21     env.render()
# ---> 22     action = act(state, 0)  # Ensure this function now returns a continuous action
#      23     state, reward, terminated, truncated, _ = env.step([action.item()])  # Execute action, note the list around action.item()
#      25     state = torch.tensor(state, device=device).float().unsqueeze(0)
#
# NameError: name 'act' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
